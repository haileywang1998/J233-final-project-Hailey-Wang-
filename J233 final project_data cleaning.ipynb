# %% [markdown]
# ## Final Project --- the relationship between depression and other diseases and habits

# %% [markdown]
# **Part 1: data cleaning**

# %% [markdown]
# **Hailey  Wang**

# %% [markdown]
# # 1. import

# %% [markdown]
# ## 1.1 import packages

# %%
import pandas as pd
import altair as alt
from scipy.stats import pearsonr
import geopandas as gpd
import numpy as np
from shapely import wkt

# %% [markdown]
# ### 1.2 import raw CDC data

# %%
cdc_places = pd.read_csv('./raw_data.csv',
                        usecols=['Year', 'StateAbbr', 'StateDesc', 'LocationName', 'Data_Value', 'TotalPopulation', 'LocationID', 'Data_Value_Type', 'Short_Question_Text', 'Geolocation'])

cdc_places
# Out:
#         Year StateAbbr      StateDesc LocationName          Data_Value_Type
# 0       2021        GA        Georgia         Ware         Crude prevalence  \
# 1       2021        IN        Indiana         Ohio         Crude prevalence
# 2       2021        IN        Indiana         Owen         Crude prevalence
# 3       2021        IA           Iowa         Iowa         Crude prevalence
# 4       2021        IA           Iowa       Marion         Crude prevalence
# ...      ...       ...            ...          ...                      ...
# 228765  2021        WA     Washington        Lewis         Crude prevalence
# 228766  2021        WI      Wisconsin         Door  Age-adjusted prevalence
# 228767  2021        WI      Wisconsin        Dodge         Crude prevalence
# 228768  2021        WV  West Virginia       Cabell  Age-adjusted prevalence
# 228769  2021        WV  West Virginia        Wayne  Age-adjusted prevalence
#
#         Data_Value  TotalPopulation  LocationID   Short_Question_Text
# 0              4.6            36033       13299                Stroke  \
# 1              3.8             5978       18115                Stroke
# 2              4.0            21446       18119                Stroke
# 3              3.3            16568       19095                Stroke
# 4              3.0            33380       19125                Stroke
# ...            ...              ...         ...                   ...
# 228765         9.6            84398       53041      Health Insurance
# 228766        22.0            30369       55029            Depression
# 228767        16.1            89313       55027       Current Smoking
# 228768        18.4            93418       54011  Cognitive Disability
# 228769        15.4            38498       54099       Physical Health
#
#                             Geolocation
# 0         POINT (-82.4215072 31.050881)
# 1         POINT (-84.9642994 38.940527)
# 2        POINT (-86.8388453 39.3173394)
# 3        POINT (-92.0591226 41.6839184)
# 4        POINT (-93.0938678 41.3314327)
# ...                                 ...
# 228765  POINT (-122.3774443 46.5800714)
# 228766   POINT (-87.0486828 45.0934165)
# 228767   POINT (-88.7019394 43.4296276)
# 228768   POINT (-82.2433966 38.4195778)
# 228769   POINT (-82.4226659 38.1436416)
#
# [228770 rows x 10 columns]

# %% [markdown]
# **Describe the database**
#
# source: https://data.cdc.gov/500-Cities-Places/PLACES-Local-Data-for-Better-Health-County-Data-20/swc5-untb
#
# time period: 2020/2021
#
# what the data can and can't tell you: It tells the county level health indicates. This dataset includes estimates for 36 measures: 13 for health outcomes, 9 for preventive services use, 4 for chronic disease-related health risk behaviors, 7 for disabilities, and 3 for health status.
#
# It has some data missing. For example, it has no depreesion rate for all counties in Florida.

# %% [markdown]
# ### 1.3 import income data

# %%
income = pd.read_csv('./new income county.csv')
income
# Out:
#         State      County   Income
# 0     Alabama     Autauga   48,914
# 1     Alabama     Baldwin   55,865
# 2     Alabama     Barbour   40,795
# 3     Alabama        Bibb   37,175
# 4     Alabama      Blount   42,852
# ...       ...         ...      ...
# 3018  Wyoming  Sweetwater   56,252
# 3019  Wyoming       Teton  362,522
# 3020  Wyoming       Uinta   44,358
# 3021  Wyoming    Washakie   54,898
# 3022  Wyoming      Weston   49,734
#
# [3023 rows x 3 columns]

# %% [markdown]
# Describe the database
#
# source: https://www.bea.gov/news/2022/personal-income-county-and-metropolitan-area-2021
#
# time period: 2021
#
# What the data can and can’t tell you: It is personal income data from the Bureau of Economic Analysis (BEA). BEA’s County and metropolitan area per capita personal income statistics are calculated by dividing personal income with population. BEA used Census population figures to calculate annual per capita personal income statistics for 2020 through 2022.

# %% [markdown]
# # 2.clean CDC data

# %% [markdown]
# ## 2.1 check for missing data

# %%
cdc_places[
    cdc_places['LocationName'].isna()]
# Out:
#        Year StateAbbr      StateDesc LocationName          Data_Value_Type
# 18     2021        US  United States          NaN  Age-adjusted prevalence  \
# 443    2021        US  United States          NaN         Crude prevalence
# 958    2021        US  United States          NaN  Age-adjusted prevalence
# 1161   2021        US  United States          NaN         Crude prevalence
# 1222   2021        US  United States          NaN         Crude prevalence
# ...     ...       ...            ...          ...                      ...
# 16314  2021        US  United States          NaN         Crude prevalence
# 17126  2021        US  United States          NaN  Age-adjusted prevalence
# 17140  2020        US  United States          NaN  Age-adjusted prevalence
# 17211  2021        US  United States          NaN         Crude prevalence
# 17223  2021        US  United States          NaN         Crude prevalence
#
#        Data_Value  TotalPopulation  LocationID        Short_Question_Text
# 18            2.8        331893745          59                     Stroke  \
# 443          10.8        331893745          59           Health Insurance
# 958          16.7        331893745          59             Binge Drinking
# 1161          7.0        331893745          59       Cancer (except skin)
# 1222         14.7        331893745          59              Mental Health
# ...           ...              ...         ...                        ...
# 16314        15.5        331893745          59             Binge Drinking
# 17126        31.0        331893745          59           High Cholesterol
# 17140        83.7        331893745          59  Cervical Cancer Screening
# 17211         3.3        331893745          59                     Stroke
# 17223        10.9        331893745          59            Physical Health
#
#       Geolocation
# 18            NaN
# 443           NaN
# 958           NaN
# 1161          NaN
# 1222          NaN
# ...           ...
# 16314         NaN
# 17126         NaN
# 17140         NaN
# 17211         NaN
# 17223         NaN
#
# [74 rows x 10 columns]

# %% [markdown]
# **It seems like we are missing data of location name and geolocation for nation level data. It makes sense because there is not a specific location or geolocation for the whole nation. And we will not need nation level data later, so I am dropping the missing national data.**

# %%
cdc_places_drop_us = cdc_places.dropna(subset = ['LocationName'])
cdc_places_drop_us
# Out:
#         Year StateAbbr      StateDesc LocationName          Data_Value_Type
# 0       2021        GA        Georgia         Ware         Crude prevalence  \
# 1       2021        IN        Indiana         Ohio         Crude prevalence
# 2       2021        IN        Indiana         Owen         Crude prevalence
# 3       2021        IA           Iowa         Iowa         Crude prevalence
# 4       2021        IA           Iowa       Marion         Crude prevalence
# ...      ...       ...            ...          ...                      ...
# 228765  2021        WA     Washington        Lewis         Crude prevalence
# 228766  2021        WI      Wisconsin         Door  Age-adjusted prevalence
# 228767  2021        WI      Wisconsin        Dodge         Crude prevalence
# 228768  2021        WV  West Virginia       Cabell  Age-adjusted prevalence
# 228769  2021        WV  West Virginia        Wayne  Age-adjusted prevalence
#
#         Data_Value  TotalPopulation  LocationID   Short_Question_Text
# 0              4.6            36033       13299                Stroke  \
# 1              3.8             5978       18115                Stroke
# 2              4.0            21446       18119                Stroke
# 3              3.3            16568       19095                Stroke
# 4              3.0            33380       19125                Stroke
# ...            ...              ...         ...                   ...
# 228765         9.6            84398       53041      Health Insurance
# 228766        22.0            30369       55029            Depression
# 228767        16.1            89313       55027       Current Smoking
# 228768        18.4            93418       54011  Cognitive Disability
# 228769        15.4            38498       54099       Physical Health
#
#                             Geolocation
# 0         POINT (-82.4215072 31.050881)
# 1         POINT (-84.9642994 38.940527)
# 2        POINT (-86.8388453 39.3173394)
# 3        POINT (-92.0591226 41.6839184)
# 4        POINT (-93.0938678 41.3314327)
# ...                                 ...
# 228765  POINT (-122.3774443 46.5800714)
# 228766   POINT (-87.0486828 45.0934165)
# 228767   POINT (-88.7019394 43.4296276)
# 228768   POINT (-82.2433966 38.4195778)
# 228769   POINT (-82.4226659 38.1436416)
#
# [228696 rows x 10 columns]

# %% [markdown]
# **We dropped 74 rows that are nation level data.**

# %% [markdown]
# ## 2.2 check data types

# %%
cdc_places_drop_us.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 228696 entries, 0 to 228769
# Data columns (total 10 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Year                 228696 non-null  int64
#  1   StateAbbr            228696 non-null  object
#  2   StateDesc            228696 non-null  object
#  3   LocationName         228696 non-null  object
#  4   Data_Value_Type      228696 non-null  object
#  5   Data_Value           228696 non-null  float64
#  6   TotalPopulation      228696 non-null  int64
#  7   LocationID           228696 non-null  int64
#  8   Short_Question_Text  228696 non-null  object
#  9   Geolocation          228696 non-null  object
# dtypes: float64(1), int64(3), object(6)
# memory usage: 19.2+ MB

# %% [markdown]
# **data type looks almost fine! But I want to change the geolocation's data type to geometry, so that I can play with the map later**

# %% [markdown]
# ### 2.2.1 adjust data type

# %%
cdc_places_drop_us['Geolocation'] = cdc_places_drop_us['Geolocation'].apply(wkt.loads)
cdc_places_drop_us_geo = gpd.GeoDataFrame(cdc_places_drop_us, geometry='Geolocation')
# Out:
# /var/folders/_p/zmr502n520jcpyzkqqhb1h580000gn/T/ipykernel_9826/1960375873.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cdc_places_drop_us['Geolocation'] = cdc_places_drop_us['Geolocation'].apply(wkt.loads)

# %%
cdc_places_drop_us_geo.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Index: 228696 entries, 0 to 228769
# Data columns (total 10 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Year                 228696 non-null  int64
#  1   StateAbbr            228696 non-null  object
#  2   StateDesc            228696 non-null  object
#  3   LocationName         228696 non-null  object
#  4   Data_Value_Type      228696 non-null  object
#  5   Data_Value           228696 non-null  float64
#  6   TotalPopulation      228696 non-null  int64
#  7   LocationID           228696 non-null  int64
#  8   Short_Question_Text  228696 non-null  object
#  9   Geolocation          228696 non-null  geometry
# dtypes: float64(1), geometry(1), int64(3), object(5)
# memory usage: 19.2+ MB

# %% [markdown]
# ## 2.3 rename columns

# %% [markdown]
# Break down each Columns. I have the years of dataset, state and state abbreviation, county, data value(%), population of each county, location ID, short question text(to tell which data value it is reffered to) and geolocation.
# I am now renaming the columns to make it clearer.
# **Change StateDesc to State; LocationName to County; Data_value to DataValue; Short_Questoin_Text to Category.**

# %%
cdc_places_drop_us_geo = cdc_places_drop_us_geo.rename(columns = {'StateDesc':'State', 'LocationName':'County', 'Data_Value':'DataValue', 'Data_Value_Type':'MeasuresOfFrequency' ,'Short_Question_Text':'Category'})
cdc_places_drop_us_geo
# Out:
#         Year StateAbbr          State  County      MeasuresOfFrequency
# 0       2021        GA        Georgia    Ware         Crude prevalence  \
# 1       2021        IN        Indiana    Ohio         Crude prevalence
# 2       2021        IN        Indiana    Owen         Crude prevalence
# 3       2021        IA           Iowa    Iowa         Crude prevalence
# 4       2021        IA           Iowa  Marion         Crude prevalence
# ...      ...       ...            ...     ...                      ...
# 228765  2021        WA     Washington   Lewis         Crude prevalence
# 228766  2021        WI      Wisconsin    Door  Age-adjusted prevalence
# 228767  2021        WI      Wisconsin   Dodge         Crude prevalence
# 228768  2021        WV  West Virginia  Cabell  Age-adjusted prevalence
# 228769  2021        WV  West Virginia   Wayne  Age-adjusted prevalence
#
#         DataValue  TotalPopulation  LocationID              Category
# 0             4.6            36033       13299                Stroke  \
# 1             3.8             5978       18115                Stroke
# 2             4.0            21446       18119                Stroke
# 3             3.3            16568       19095                Stroke
# 4             3.0            33380       19125                Stroke
# ...           ...              ...         ...                   ...
# 228765        9.6            84398       53041      Health Insurance
# 228766       22.0            30369       55029            Depression
# 228767       16.1            89313       55027       Current Smoking
# 228768       18.4            93418       54011  Cognitive Disability
# 228769       15.4            38498       54099       Physical Health
#
#                         Geolocation
# 0        POINT (-82.42151 31.05088)
# 1        POINT (-84.96430 38.94053)
# 2        POINT (-86.83885 39.31734)
# 3        POINT (-92.05912 41.68392)
# 4        POINT (-93.09387 41.33143)
# ...                             ...
# 228765  POINT (-122.37744 46.58007)
# 228766   POINT (-87.04868 45.09342)
# 228767   POINT (-88.70194 43.42963)
# 228768   POINT (-82.24340 38.41958)
# 228769   POINT (-82.42267 38.14364)
#
# [228696 rows x 10 columns]

# %% [markdown]
# ## 2.4 look for duplicates

# %%
len(cdc_places_drop_us_geo)
# Out:
# 228696

# %% [markdown]
# **It originally has 228696 rows. Now let's see if there are any duplicates.**

# %%
cdc_places_drop_us_geo_duplicate = cdc_places_drop_us_geo[cdc_places_drop_us_geo.duplicated(subset=['State', 'County', 'Category'])]
cdc_places_drop_us_geo_duplicate
# Out:
#         Year StateAbbr          State     County      MeasuresOfFrequency
# 318     2021        AL        Alabama    Madison         Crude prevalence  \
# 334     2021        AL        Alabama    Calhoun         Crude prevalence
# 359     2021        AL        Alabama    Choctaw  Age-adjusted prevalence
# 368     2021        CA     California  Calaveras         Crude prevalence
# 407     2021        AR       Arkansas      Clark         Crude prevalence
# ...      ...       ...            ...        ...                      ...
# 228765  2021        WA     Washington      Lewis         Crude prevalence
# 228766  2021        WI      Wisconsin       Door  Age-adjusted prevalence
# 228767  2021        WI      Wisconsin      Dodge         Crude prevalence
# 228768  2021        WV  West Virginia     Cabell  Age-adjusted prevalence
# 228769  2021        WV  West Virginia      Wayne  Age-adjusted prevalence
#
#         DataValue  TotalPopulation  LocationID                       Category
# 318           3.0           395211        1089                         Stroke  \
# 334          22.7           115972        1015                     Depression
# 359          13.8            12533        1023                 Binge Drinking
# 368           9.9            46221        6009                 Current Asthma
# 407           9.6            21321        5019  Independent Living Disability
# ...           ...              ...         ...                            ...
# 228765        9.6            84398       53041               Health Insurance
# 228766       22.0            30369       55029                     Depression
# 228767       16.1            89313       55027                Current Smoking
# 228768       18.4            93418       54011           Cognitive Disability
# 228769       15.4            38498       54099                Physical Health
#
#                         Geolocation
# 318      POINT (-86.55108 34.76424)
# 334      POINT (-85.82791 33.77052)
# 359      POINT (-88.24889 31.99095)
# 368     POINT (-120.55411 38.19107)
# 407      POINT (-93.17621 34.05332)
# ...                             ...
# 228765  POINT (-122.37744 46.58007)
# 228766   POINT (-87.04868 45.09342)
# 228767   POINT (-88.70194 43.42963)
# 228768   POINT (-82.24340 38.41958)
# 228769   POINT (-82.42267 38.14364)
#
# [114348 rows x 10 columns]

# %% [markdown]
# **There are 114348 duplicates. It's exactly half of the number. What are they?**

# %% [markdown]
# There are two types of measures of frequency. According to CDC Places'description, age-adjusted prevalence is the standardized data of crude-prevalence data by the direct method to the year 2000 standard U.S. population, distribution 22 with 95% confidence intervals and by demographic characteristics when feasible. We will use age-adjusted data here, so I'm dropping all of the crude-prevalence data.

# %%
mask = cdc_places_drop_us_geo['MeasuresOfFrequency'] == 'Crude prevalence'
cdc_places_cleaned = cdc_places_drop_us_geo[~mask]
cdc_places_cleaned
# Out:
#         Year StateAbbr          State      County      MeasuresOfFrequency
# 10      2021        CA     California   Calaveras  Age-adjusted prevalence  \
# 11      2021        AL        Alabama     Fayette  Age-adjusted prevalence
# 12      2021        AR       Arkansas      Benton  Age-adjusted prevalence
# 13      2021        AL        Alabama     Calhoun  Age-adjusted prevalence
# 16      2020        CA     California  Sacramento  Age-adjusted prevalence
# ...      ...       ...            ...         ...                      ...
# 228763  2021        WY        Wyoming    Sublette  Age-adjusted prevalence
# 228764  2021        WI      Wisconsin  Green Lake  Age-adjusted prevalence
# 228766  2021        WI      Wisconsin        Door  Age-adjusted prevalence
# 228768  2021        WV  West Virginia      Cabell  Age-adjusted prevalence
# 228769  2021        WV  West Virginia       Wayne  Age-adjusted prevalence
#
#         DataValue  TotalPopulation  LocationID
# 10           10.3            46221        6009  \
# 11            6.9            16148        1057
# 12           13.7           293692        5007
# 13           34.1           115972        1015
# 16           38.2          1588921        6067
# ...           ...              ...         ...
# 228763        3.7             8697       56035
# 228764       28.1            19229       55047
# 228766       22.0            30369       55029
# 228768       18.4            93418       54011
# 228769       15.4            38498       54099
#
#                                       Category                  Geolocation
# 10                              Current Asthma  POINT (-120.55411 38.19107)
# 11                      Coronary Heart Disease   POINT (-87.76429 33.71616)
# 12                        Cognitive Disability   POINT (-94.25630 36.33782)
# 13                         Physical Inactivity   POINT (-85.82791 33.77052)
# 16      Core preventive services for older men  POINT (-121.34433 38.45014)
# ...                                        ...                          ...
# 228763                       Vision Disability  POINT (-109.91617 42.76793)
# 228764                     High Blood Pressure   POINT (-88.97038 43.78025)
# 228766                              Depression   POINT (-87.04868 45.09342)
# 228768                    Cognitive Disability   POINT (-82.24340 38.41958)
# 228769                         Physical Health   POINT (-82.42267 38.14364)
#
# [114348 rows x 10 columns]

# %%
len(cdc_places_cleaned)
# Out:
# 114348

# %% [markdown]
# **I dropped half of the data. With no duplicates,now I get 114348 rows left.**

# %%
cdc_places_cleaned.to_csv(r'/Users/Owner/Documents/school work/J233/cleaned cdc places with python.csv', index=False)

# %% [markdown]
# ## 2.5 look for depression value

# %%
cdc_places_depression = cdc_places_cleaned[cdc_places_cleaned['Category'] == 'Depression']
cdc_places_depression.sort_values('StateAbbr')
# Out:
#         Year StateAbbr    State            County      MeasuresOfFrequency
# 3365    2021        AK   Alaska            Juneau  Age-adjusted prevalence  \
# 11914   2021        AK   Alaska            Denali  Age-adjusted prevalence
# 1924    2021        AK   Alaska  Northwest Arctic  Age-adjusted prevalence
# 11848   2021        AK   Alaska        Dillingham  Age-adjusted prevalence
# 7566    2021        AK   Alaska              Nome  Age-adjusted prevalence
# ...      ...       ...      ...               ...                      ...
# 216518  2021        WY  Wyoming        Sweetwater  Age-adjusted prevalence
# 221452  2021        WY  Wyoming            Platte  Age-adjusted prevalence
# 216316  2021        WY  Wyoming           Johnson  Age-adjusted prevalence
# 219614  2021        WY  Wyoming            Albany  Age-adjusted prevalence
# 216236  2021        WY  Wyoming             Teton  Age-adjusted prevalence
#
#         DataValue  TotalPopulation  LocationID    Category
# 3365         20.2            31973        2110  Depression  \
# 11914        19.9             1593        2068  Depression
# 1924         20.3             7560        2188  Depression
# 11848        20.3             4772        2070  Depression
# 7566         19.8             9865        2180  Depression
# ...           ...              ...         ...         ...
# 216518       20.2            41614       56037  Depression
# 221452       20.1             8699       56031  Depression
# 216316       20.7             8623       56019  Depression
# 219614       21.4            37608       56001  Depression
# 216236       17.4            23575       56039  Depression
#
#                         Geolocation
# 3365    POINT (-134.17845 58.37291)
# 11914   POINT (-150.02702 63.68204)
# 1924    POINT (-160.02109 67.00507)
# 11848   POINT (-158.26712 59.54333)
# 7566    POINT (-164.18891 64.78369)
# ...                             ...
# 216518  POINT (-108.87568 41.66033)
# 221452  POINT (-104.95396 42.13159)
# 216316  POINT (-106.58854 44.04405)
# 219614  POINT (-105.72188 41.66551)
# 216236  POINT (-110.42609 44.04866)
#
# [3076 rows x 10 columns]

# %% [markdown]
# # 3. clean income data

# %%
combine_depression_income = pd.merge(
    cdc_places_depression,
    income, 
    how='outer', 
    on=['State','County'],
    #validate='1:1' 
)

combine_depression_income
# Out:
#         Year StateAbbr    State       County      MeasuresOfFrequency
# 0     2021.0        AL  Alabama      Cullman  Age-adjusted prevalence  \
# 1     2021.0        AK   Alaska  Bristol Bay  Age-adjusted prevalence
# 2     2021.0        AL  Alabama      Calhoun  Age-adjusted prevalence
# 3     2021.0        AL  Alabama      Conecuh  Age-adjusted prevalence
# 4     2021.0        AL  Alabama       Etowah  Age-adjusted prevalence
# ...      ...       ...      ...          ...                      ...
# 3259     NaN       NaN     Utah       Orange                      NaN
# 3260     NaN       NaN     Utah      Orleans                      NaN
# 3261     NaN       NaN     Utah      Rutland                      NaN
# 3262     NaN       NaN     Utah      Windham                      NaN
# 3263     NaN       NaN     Utah      Windsor                      NaN
#
#       DataValue  TotalPopulation  LocationID    Category
# 0          25.2          89496.0      1043.0  Depression  \
# 1          18.8            838.0      2060.0  Depression
# 2          23.3         115972.0      1015.0  Depression
# 3          23.1          11328.0      1035.0  Depression
# 4          25.0         103162.0      1055.0  Depression
# ...         ...              ...         ...         ...
# 3259        NaN              NaN         NaN         NaN
# 3260        NaN              NaN         NaN         NaN
# 3261        NaN              NaN         NaN         NaN
# 3262        NaN              NaN         NaN         NaN
# 3263        NaN              NaN         NaN         NaN
#
#                       Geolocation  Income
# 0      POINT (-86.86927 34.13192)  46,762
# 1     POINT (-156.96681 58.74166)     NaN
# 2      POINT (-85.82791 33.77052)  43,045
# 3      POINT (-86.98872 31.43093)  40,467
# 4      POINT (-86.03426 34.04764)  42,571
# ...                           ...     ...
# 3259                         None  55,304
# 3260                         None  52,213
# 3261                         None  56,441
# 3262                         None  55,590
# 3263                         None  66,958
#
# [3264 rows x 11 columns]

# %%
combine_depression_income.dropna()
# Out:
#         Year StateAbbr       State        County      MeasuresOfFrequency
# 0     2021.0        AL     Alabama       Cullman  Age-adjusted prevalence  \
# 2     2021.0        AL     Alabama       Calhoun  Age-adjusted prevalence
# 3     2021.0        AL     Alabama       Conecuh  Age-adjusted prevalence
# 4     2021.0        AL     Alabama        Etowah  Age-adjusted prevalence
# 5     2021.0        AR    Arkansas           Lee  Age-adjusted prevalence
# ...      ...       ...         ...           ...                      ...
# 3109  2021.0        WA  Washington     Jefferson  Age-adjusted prevalence
# 3110  2021.0        WA  Washington  Grays Harbor  Age-adjusted prevalence
# 3111  2021.0        WI   Wisconsin       Calumet  Age-adjusted prevalence
# 3112  2021.0        WI   Wisconsin        Monroe  Age-adjusted prevalence
# 3113  2021.0        WI   Wisconsin          Door  Age-adjusted prevalence
#
#       DataValue  TotalPopulation  LocationID    Category
# 0          25.2          89496.0      1043.0  Depression  \
# 2          23.3         115972.0      1015.0  Depression
# 3          23.1          11328.0      1035.0  Depression
# 4          25.0         103162.0      1055.0  Depression
# 5          22.8           8619.0      5077.0  Depression
# ...         ...              ...         ...         ...
# 3109       28.0          33605.0     53031.0  Depression
# 3110       28.4          76841.0     53027.0  Depression
# 3111       21.9          52539.0     55015.0  Depression
# 3112       23.9          46193.0     55081.0  Depression
# 3113       22.0          30369.0     55029.0  Depression
#
#                       Geolocation  Income
# 0      POINT (-86.86927 34.13192)  46,762
# 2      POINT (-85.82791 33.77052)  43,045
# 3      POINT (-86.98872 31.43093)  40,467
# 4      POINT (-86.03426 34.04764)  42,571
# 5      POINT (-90.77972 34.77950)  39,589
# ...                           ...     ...
# 3109  POINT (-123.52706 47.80571)  61,489
# 3110  POINT (-123.82673 47.11373)  47,304
# 3111   POINT (-88.21213 44.07841)  58,066
# 3112   POINT (-90.61997 43.94518)  49,825
# 3113   POINT (-87.04868 45.09342)  70,363
#
# [2873 rows x 11 columns]

# %% [markdown]
# The depression info is from CDC, and income data is from BEA. Because the datasets have different sizes with some counties missing in one or the other, there will be some gaps when merging. So, I'm just getting rid of those gaps.

# %%
combine_depression_income.to_csv(r'/Users/Owner/Documents/school work/J233/combine_depression_income with python.csv', index=False)
